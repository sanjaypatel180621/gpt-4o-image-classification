# %% [markdown]
# # Image classification with Azure OpenAI gpt-4o
# ## Use-case: Flowers dataset

# %%
# %pip install openai --upgrade
# Out:
# Collecting openai
#   Downloading openai-2.28.0-py3-none-any.whl.metadata (29 kB)
# Collecting anyio<5,>=3.5.0 (from openai)
#   Downloading anyio-4.12.1-py3-none-any.whl.metadata (4.3 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Downloading distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting httpx<1,>=0.23.0 (from openai)
#   Downloading httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Downloading jiter-0.13.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting pydantic<3,>=1.9.0 (from openai)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
#      ---------------------------------------- 0.0/90.6 kB ? eta -:--:--
#      ---- ----------------------------------- 10.2/90.6 kB ? eta -:--:--
#      ------------------------------------ --- 81.9/90.6 kB 1.2 MB/s eta 0:00:01
#      ---------------------------------------- 90.6/90.6 kB 1.0 MB/s eta 0:00:00
# Collecting sniffio (from openai)
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting tqdm>4 (from openai)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.7 kB ? eta -:--:--
#      ---------------------------------------- 57.7/57.7 kB 3.2 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from openai) (4.15.0)
# Collecting idna>=2.8 (from anyio<5,>=3.5.0->openai)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting certifi (from httpx<1,>=0.23.0->openai)
#   Downloading certifi-2026.2.25-py3-none-any.whl.metadata (2.5 kB)
# Collecting httpcore==1.* (from httpx<1,>=0.23.0->openai)
#   Downloading httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# Collecting h11>=0.16 (from httpcore==1.*->httpx<1,>=0.23.0->openai)
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.9.0->openai)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=1.9.0->openai)
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=1.9.0->openai)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: colorama in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>4->openai) (0.4.6)
# Downloading openai-2.28.0-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    ---------------------------------------  1.1/1.1 MB 36.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 24.1 MB/s eta 0:00:00
# Downloading anyio-4.12.1-py3-none-any.whl (113 kB)
#    ---------------------------------------- 0.0/113.6 kB ? eta -:--:--
#    ---------------------------------------- 113.6/113.6 kB 6.9 MB/s eta 0:00:00
# Downloading distro-1.9.0-py3-none-any.whl (20 kB)
# Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 4.2 MB/s eta 0:00:00
# Downloading httpcore-1.0.9-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.8 kB ? eta -:--:--
#    ---------------------------------------- 78.8/78.8 kB 4.3 MB/s eta 0:00:00
# Downloading jiter-0.13.0-cp311-cp311-win_amd64.whl (204 kB)
#    ---------------------------------------- 0.0/204.6 kB ? eta -:--:--
#    --------------------------------------- 204.6/204.6 kB 12.1 MB/s eta 0:00:00
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#    ---------------------------------------- 0.0/463.6 kB ? eta -:--:--
#    --------------------------------------- 463.6/463.6 kB 28.3 MB/s eta 0:00:00
# Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------  2.0/2.0 MB 64.4 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 43.5 MB/s eta 0:00:00
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
#    ---------------------------------------- 0.0/78.4 kB ? eta -:--:--
#    ---------------------------------------- 78.4/78.4 kB 4.3 MB/s eta 0:00:00
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
#    ---------------------------------------- 0.0/71.0 kB ? eta -:--:--
#    ---------------------------------------- 71.0/71.0 kB 3.8 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading certifi-2026.2.25-py3-none-any.whl (153 kB)
#    ---------------------------------------- 0.0/153.7 kB ? eta -:--:--
#    ---------------------------------------- 153.7/153.7 kB 9.0 MB/s eta 0:00:00
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Installing collected packages: typing-inspection, tqdm, sniffio, pydantic-core, jiter, idna, h11, distro, certifi, annotated-types, pydantic, httpcore, anyio, httpx, openai
# Successfully installed annotated-types-0.7.0 anyio-4.12.1 certifi-2026.2.25 distro-1.9.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 idna-3.11 jiter-0.13.0 openai-2.28.0 pydantic-2.12.5 pydantic-core-2.41.5 sniffio-1.3.1 tqdm-4.67.3 typing-inspection-0.4.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
! pip install ipyplot matplotlib seaborn dotenv scikit-learn
# Out:
# Collecting ipyplot
#   Downloading ipyplot-1.1.2-py3-none-any.whl.metadata (7.2 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
#      ---------------------------------------- 0.0/52.8 kB ? eta -:--:--
#      -------------- ----------------------- 20.5/52.8 kB 217.9 kB/s eta 0:00:01
#      -------------- ----------------------- 20.5/52.8 kB 217.9 kB/s eta 0:00:01
#      ---------------------- --------------- 30.7/52.8 kB 145.2 kB/s eta 0:00:01
#      ---------------------- --------------- 30.7/52.8 kB 145.2 kB/s eta 0:00:01
#      -------------------------------------- 52.8/52.8 kB 194.5 kB/s eta 0:00:00
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting dotenv
#   Downloading dotenv-0.9.9-py2.py3-none-any.whl.metadata (279 bytes)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: IPython in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from ipyplot) (9.10.0)
# Collecting numpy (from ipyplot)
#   Downloading numpy-2.4.3-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting pillow (from ipyplot)
#   Downloading pillow-12.1.1-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting shortuuid (from ipyplot)
#   Downloading shortuuid-1.0.13-py3-none-any.whl.metadata (5.8 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp311-cp311-win_amd64.whl.metadata (119 kB)
#      ---------------------------------------- 0.0/119.8 kB ? eta -:--:--
#      -------------------------------------- 119.8/119.8 kB 2.3 MB/s eta 0:00:00
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl.metadata (5.2 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (26.0)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from matplotlib) (2.9.0.post0)
# Collecting pandas>=1.2 (from seaborn)
#   Downloading pandas-3.0.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting python-dotenv (from dotenv)
#   Downloading python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB 3.2 MB/s eta 0:00:00
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting tzdata (from pandas>=1.2->seaborn)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from IPython->ipyplot) (4.15.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jedi>=0.18.1->IPython->ipyplot) (0.8.6)
# Requirement already satisfied: wcwidth in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython->ipyplot) (0.6.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data>=0.6.0->IPython->ipyplot) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data>=0.6.0->IPython->ipyplot) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\admin\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from stack_data>=0.6.0->IPython->ipyplot) (0.2.3)
# Downloading ipyplot-1.1.2-py3-none-any.whl (13 kB)
# Downloading matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------- ------------------------- 3.0/8.1 MB 48.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.7/8.1 MB 61.6 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------ --------- 6.2/8.1 MB 56.4 MB/s eta 0:00:01
#    ------------------------------- -------- 6.4/8.1 MB 8.9 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 10.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.4 MB/s eta 0:00:00
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    --------------------------------------- 294.9/294.9 kB 19.0 MB/s eta 0:00:00
# Downloading dotenv-0.9.9-py2.py3-none-any.whl (1.9 kB)
# Downloading scikit_learn-1.8.0-cp311-cp311-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------- ---------------------------- 2.3/8.1 MB 75.0 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ------------------- -------------------- 3.8/8.1 MB 60.8 MB/s eta 0:00:01
#    ----------------------------- ---------- 6.0/8.1 MB 8.7 MB/s eta 0:00:01
#    ---------------------------------------  8.1/8.1 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.5 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
#    ---------------------------------------- 0.0/225.2 kB ? eta -:--:--
#    --------------------------------------- 225.2/225.2 kB 13.4 MB/s eta 0:00:00
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp311-cp311-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.7/2.3 MB 53.2 MB/s eta 0:00:01
#    ---------------------------------------  2.3/2.3 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.3/2.3 MB 3.6 MB/s eta 0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#    ---------------------------------------- 0.0/309.1 kB ? eta -:--:--
#    --------------------------------------- 309.1/309.1 kB 18.7 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp311-cp311-win_amd64.whl (73 kB)
#    ---------------------------------------- 0.0/73.5 kB ? eta -:--:--
#    ---------------------------------------- 73.5/73.5 kB 4.0 MB/s eta 0:00:00
# Downloading numpy-2.4.3-cp311-cp311-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------- ------------------------------ 2.9/12.6 MB 62.3 MB/s eta 0:00:01
#    -------------- ------------------------- 4.6/12.6 MB 49.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.0/12.6 MB 46.2 MB/s eta 0:00:01
#    ------------------- -------------------- 6.1/12.6 MB 8.3 MB/s eta 0:00:01
#    ------------------------- -------------- 8.2/12.6 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.9/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.6 MB 12.6 MB/s eta 0:00:01
#    ---------------------------------------  12.6/12.6 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 7.0 MB/s eta 0:00:00
# Downloading pandas-3.0.1-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ------------ --------------------------- 3.0/9.9 MB 64.3 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.7/9.9 MB 60.7 MB/s eta 0:00:01
#    ------------------- -------------------- 4.9/9.9 MB 7.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.2/9.9 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 11.9 MB/s eta 0:00:00
# Downloading pillow-12.1.1-cp311-cp311-win_amd64.whl (7.0 MB)
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.0/7.0 MB 65.5 MB/s eta 0:00:01
#    ------- -------------------------------- 1.3/7.0 MB 2.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 4.1/7.0 MB 6.0 MB/s eta 0:00:01
#    ---------------------------------------  7.0/7.0 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 7.0/7.0 MB 9.2 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
#    ---------------------------------------- 0.0/122.8 kB ? eta -:--:--
#    ---------------------------------------- 122.8/122.8 kB 7.5 MB/s eta 0:00:00
# Downloading scipy-1.17.1-cp311-cp311-win_amd64.whl (36.6 MB)
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/36.6 MB ? eta -:--:--
#    - -------------------------------------- 1.0/36.6 MB 64.6 MB/s eta 0:00:01
#    --- ------------------------------------ 3.5/36.6 MB 55.6 MB/s eta 0:00:01
#    ------ --------------------------------- 6.1/36.6 MB 56.3 MB/s eta 0:00:01
#    ------ --------------------------------- 6.1/36.6 MB 56.3 MB/s eta 0:00:01
#    ------ --------------------------------- 6.1/36.6 MB 56.3 MB/s eta 0:00:01
#    ------ --------------------------------- 6.1/36.6 MB 56.3 MB/s eta 0:00:01
#    ------ --------------------------------- 6.1/36.6 MB 56.3 MB/s eta 0:00:01
#    ------- -------------------------------- 7.2/36.6 MB 20.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 9.3/36.6 MB 23.9 MB/s eta 0:00:02
#    ------------- -------------------------- 12.1/36.6 MB 25.1 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    ------------- -------------------------- 12.3/36.6 MB 25.2 MB/s eta 0:00:01
#    -------------- ------------------------- 13.7/36.6 MB 9.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 15.9/36.6 MB 9.9 MB/s eta 0:00:03
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    -------------------- ------------------- 18.5/36.6 MB 12.6 MB/s eta 0:00:02
#    --------------------- ------------------ 19.6/36.6 MB 7.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 21.6/36.6 MB 7.0 MB/s eta 0:00:03
#    -------------------------- ------------- 24.0/36.6 MB 12.3 MB/s eta 0:00:02
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    -------------------------- ------------- 24.6/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------- ------------ 25.5/36.6 MB 7.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 27.2/36.6 MB 7.0 MB/s eta 0:00:02
#    -------------------------------- ------- 29.4/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    --------------------------------- ------ 30.8/36.6 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 31.5/36.6 MB 7.0 MB/s eta 0:00:01
#    ------------------------------------ --- 33.4/36.6 MB 7.0 MB/s eta 0:00:01
#    ---------------------------------------  36.2/36.6 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  36.6/36.6 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------- 36.6/36.6 MB 10.6 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Downloading shortuuid-1.0.13-py3-none-any.whl (10 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
#    ---------------------------------------- 0.0/348.5 kB ? eta -:--:--
#    --------------------------- ------------ 235.5/348.5 kB ? eta -:--:--
#    --------------------------- ------------ 235.5/348.5 kB ? eta -:--:--
#    --------------------------- ------------ 235.5/348.5 kB ? eta -:--:--
#    --------------------------- ------------ 235.5/348.5 kB ? eta -:--:--
#    ----------------------------- ---------- 256.0/348.5 kB 1.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 256.0/348.5 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 348.5/348.5 kB 1.1 MB/s eta 0:00:00
# Installing collected packages: tzdata, threadpoolctl, shortuuid, python-dotenv, pyparsing, pillow, numpy, kiwisolver, joblib, fonttools, cycler, scipy, pandas, dotenv, contourpy, scikit-learn, matplotlib, ipyplot, seaborn
# Successfully installed contourpy-1.3.3 cycler-0.12.1 dotenv-0.9.9 fonttools-4.62.1 ipyplot-1.1.2 joblib-1.5.3 kiwisolver-1.5.0 matplotlib-3.10.8 numpy-2.4.3 pandas-3.0.1 pillow-12.1.1 pyparsing-3.3.2 python-dotenv-1.2.2 scikit-learn-1.8.0 scipy-1.17.1 seaborn-0.13.2 shortuuid-1.0.13 threadpoolctl-3.6.0 tzdata-2025.3
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\Admin\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import base64
import glob
import ipyplot
import matplotlib.pyplot as plt
import numpy as np
import openai
import os
import pandas as pd
import seaborn as sns
import sys

from datetime import datetime
from dotenv import load_dotenv
from mimetypes import guess_type
from openai import AzureOpenAI
from PIL import Image
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
sys.version
# Out:
# '3.11.9 (tags/v3.11.9:de54cf5, Apr  2 2024, 10:12:12) [MSC v.1938 64 bit (AMD64)]'

# %%
print(f"Azure OpenAI version: {openai.__version__}")
# Out:
# Azure OpenAI version: 2.28.0

# %%
now = datetime.now()
today = now.strftime("%Y-%m-%d %H:%M:%S")
print(f"Today is {today}")
# Out:
# Today is 2026-03-16 22:50:46

# %%
load_dotenv("azure.env")

aoai_key = os.getenv("api_key")
aoai_endpoint = os.getenv("azure_endpoint")

model = "gpt-4o"  # Azure OpenAI model to use

# %% [markdown]
# ## Helper

# %%
def count_image_files(path):
    """
    Counts and prints the number of image files in each subdirectory of the given directory.

    Args:
        path (str): The path to the directory to search for image files.
    """
    image_extensions = {'.jpg', '.jpeg', '.png', '.gif', '.bmp', '.tiff'}
    nb_images = 0

    for root, dirs, files in os.walk(path):
        dirs[:] = [d for d in dirs if d != '.ipynb_checkpoints']
        for subdir in dirs:
            subdir_path = os.path.join(root, subdir)
            num_image_files = len([f for f in os.listdir(subdir_path) 
                                   if os.path.isfile(os.path.join(subdir_path, f)) and 
                                   os.path.splitext(f)[1].lower() in image_extensions])
            print(f"{subdir_path} | Number of image files = {num_image_files}")
            nb_images += num_image_files

    print(f"\nTotal number of images files = {nb_images}")

# %%
def display_image(image_file):
    """
    Display an image file.

    This function checks if the specified image file exists. 
    If the file exists, it opens and displays the image.
    If the file does not exist, it prints an error message.

    Parameters:
    image_file (str): The path to the image file to be displayed.

    Returns:
    None
    """
    if not os.path.exists(image_file):
        print(f"[Error] Image file {image_file} does not exist.")
        return None

    else:
        print(f"Image file to classify: {image_file}")
        img = Image.open(image_file)
        display(img)

# %%
def local_image_to_url(image_file):
    """
    Convert a local image file to a data URL.

    This function checks if the specified image file exists. If the file exists, it reads the file,
    encodes its content in base64, and returns a data URL that can be used to embed the image in web pages.
    If the file does not exist, it prints an error message and returns None.
    """
    if not os.path.exists(image_file):
        print(f"[Error] Image file {image_file} does not exist.")
        return None
    
    else:
        mime_type, _ = guess_type(image_file)
        if mime_type is None:
            mime_type = 'application/octet-stream'
        with open(image_file, "rb") as imagefile:
            base64_encoded_data = base64.b64encode(
                imagefile.read()).decode('utf-8')
        return f"data:{mime_type};base64,{base64_encoded_data}"

# %%
def get_image_classification(image_file, model=model):
    """
    Classify an image using an Azure OpenAI model.

    This function takes an image file and uses an Azure OpenAI model to classify the image.
    It constructs a prompt for the model to analyze the image and return a classification from a 
    predefined list of classes.
    If the model cannot determine the class, it returns 'unknown'.

    Parameters:
    image_file (str): The path to the image file to be classified.
    model (str): The name of the Azure OpenAI model to be used for classification.

    Returns:
    str: The classification result from the model.
    """
    # Azure OpenAI client
    aoai_client = AzureOpenAI(api_key=aoai_key,
                              api_version="2024-10-21",
                              azure_endpoint=aoai_endpoint)

    prompt = f"""
    Analyze the provided image of flowers There are four classes of metal defects in the surface: {class_labels}.
    You must always return only one word value from that list. If you do not know always choose 'unknown'.
    """
    # Results
    response = aoai_client.chat.completions.create(
        model=model,
        messages=[{
            "role": "system",
            "content": "You are a helpful assistant to analyse image."
        }, {
            "role":
            "user",
            "content": [{
                "type": "text",
                "text": prompt
            }, {
                "type": "image_url",
                "image_url": {
                    "url": f"{local_image_to_url(image_file)}"
                }
            }]
        }],
        max_tokens=800,
        temperature=0.,
        top_p=1,
        presence_penalty=1,
    )

    return response.choices[0].message.content

# %% [markdown]
# ## Image classification

# %%
IMAGES_DIR = "flowers_images"

# %%
count_image_files(IMAGES_DIR)
# Out:
# flowers_images\class1 | Number of image files = 10
# flowers_images\class2 | Number of image files = 10
# flowers_images\class3 | Number of image files = 10
# flowers_images\class4 | Number of image files = 10
#
# Total number of images files = 40

# %%
images = glob.glob(IMAGES_DIR +  '/**/*.*')
labels = [image.split('/')[-2] if len(image.split('/')) >= 2 else 'unknown' for image in images]

ipyplot.plot_class_tabs(images, labels, max_imgs_per_tab=5, img_width=170)
# Out:
#     <style>
#         #ipyplot-html-viewer-toggle-4EkrmAq4xaG2rKBXEE4qHS {
#             position: absolute;
#             top: -9999px;
#             left: -9999px;
#             visibility: hidden;
#         }
#
#         #ipyplot-html-viewer-label-4EkrmAq4xaG2rKBXEE4qHS {
#             position: relative;
#             display: inline-block;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#
#         #ipyplot-html-viewer-textarea-4EkrmAq4xaG2rKBXEE4qHS {
#             background: lightgrey;
#             width: 100%;
#             height: 0px;
#             display: none;
#         }
#
#         #ipyplot-html-viewer-toggle-4EkrmAq4xaG2rKBXEE4qHS:checked ~ #ipyplot-html-viewer-textarea-4EkrmAq4xaG2rKBXEE4qHS {
#             height: 200px;
#             display: block;
#         }
#
#         #ipyplot-html-viewer-toggle-4EkrmAq4xaG2rKBXEE4qHS:checked + #ipyplot-html-viewer-label-4EkrmAq4xaG2rKBXEE4qHS:after {
#             content: "hide html";
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: white;
#             cursor: pointer;
#             color: blue;
#             text-decoration: underline;
#         }
#     </style>
#     <div>
#         <input type="checkbox" id="ipyplot-html-viewer-toggle-4EkrmAq4xaG2rKBXEE4qHS">
#         <label id="ipyplot-html-viewer-label-4EkrmAq4xaG2rKBXEE4qHS" for="ipyplot-html-viewer-toggle-4EkrmAq4xaG2rKBXEE4qHS">show html</label>
#         <textarea id="ipyplot-html-viewer-textarea-4EkrmAq4xaG2rKBXEE4qHS" readonly>
#             <div>
#         <style>
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5 {
#                 display: none;
#             }
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5 + label.ipyplot-tab-label-4ouT8EWwb7aQouVWm44MV5 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5:checked + label.ipyplot-tab-label-4ouT8EWwb7aQouVWm44MV5 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5 ~ .tab {
#                 display: none
#             }
#     #tabf6nLmembGG46HjhhisBRwh:checked ~ .tab.contentf6nLmembGG46HjhhisBRwh{ display: block; }</style><input class="ipyplot-tab-4ouT8EWwb7aQouVWm44MV5" type="radio" name="tabs-4ouT8EWwb7aQouVWm44MV5" id="tabf6nLmembGG46HjhhisBRwh" checked /><label class="ipyplot-tab-label-4ouT8EWwb7aQouVWm44MV5" for="tabf6nLmembGG46HjhhisBRwh">unknown</label><div class="tab contentf6nLmembGG46HjhhisBRwh">
#         <style>
#         #ipyplot-imgs-container-div-akkuMuAn3GmQAtrykQiup2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2 {
#             width: 170px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 {
#             width: 170px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 img {
#             width: 170px;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-akkuMuAn3GmQAtrykQiup2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-akkuMuAn3GmQAtrykQiup2]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-akkuMuAn3GmQAtrykQiup2]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-akkuMuAn3GmQAtrykQiup2">
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-RDbHfErbRxbpnGNJYYPGEt" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (1).jpg</h4><img src="flowers_images\class1\dandelion (1).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-RDbHfErbRxbpnGNJYYPGEt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-dVnT3o6g7Ryfn9GDTR8Hsh" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (10).jpg</h4><img src="flowers_images\class1\dandelion (10).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-dVnT3o6g7Ryfn9GDTR8Hsh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-HG3bPNcbcejyBQVWVH2wXB" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (2).jpg</h4><img src="flowers_images\class1\dandelion (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-HG3bPNcbcejyBQVWVH2wXB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-DDJ5ToyK3Gnf3GrSgzYHBq" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (3).jpg</h4><img src="flowers_images\class1\dandelion (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-DDJ5ToyK3Gnf3GrSgzYHBq">
# <div>
#         <style>
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5 {
#                 display: none;
#             }
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5 + label.ipyplot-tab-label-4ouT8EWwb7aQouVWm44MV5 {
#                 border: 1px solid #999;
#                 background: #EEE;
#                 padding: 4px 12px;
#                 border-radius: 4px 4px 0 0;
#                 position: relative;
#                 top: 1px;
#             }
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5:checked + label.ipyplot-tab-label-4ouT8EWwb7aQouVWm44MV5 {
#                 background: #FFF;
#                 border-bottom: 1px solid transparent;
#             }
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5 ~ .tab {
#                 border-top: 1px solid #999;
#                 padding: 12px;
#             }
#
#             input.ipyplot-tab-4ouT8EWwb7aQouVWm44MV5 ~ .tab {
#                 display: none
#             }
#     #tabf6nLmembGG46HjhhisBRwh:checked ~ .tab.contentf6nLmembGG46HjhhisBRwh{ display: block; }</style><input class="ipyplot-tab-4ouT8EWwb7aQouVWm44MV5" type="radio" name="tabs-4ouT8EWwb7aQouVWm44MV5" id="tabf6nLmembGG46HjhhisBRwh" checked /><label class="ipyplot-tab-label-4ouT8EWwb7aQouVWm44MV5" for="tabf6nLmembGG46HjhhisBRwh">unknown</label><div class="tab contentf6nLmembGG46HjhhisBRwh">
#         <style>
#         #ipyplot-imgs-container-div-akkuMuAn3GmQAtrykQiup2 {
#             width: 100%;
#             height: 100%;
#             margin: 0%;
#             overflow: auto;
#             position: relative;
#             overflow-y: scroll;
#         }
#
#         div.ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2 {
#             width: 170px;
#             display: inline-block;
#             margin: 3px;
#             position: relative;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 {
#             width: 170px;
#             background: white;
#             display: inline-block;
#             vertical-align: top;
#             text-align: center;
#             position: relative;
#             border: 2px solid #ddd;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 span.ipyplot-img-close {
#             display: none;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 span {
#             width: 100%;
#             height: 100%;
#             position: absolute;
#             top: 0;
#             left: 0;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 img {
#             width: 170px;
#         }
#
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 span.ipyplot-img-close:hover {
#             cursor: zoom-out;
#         }
#         div.ipyplot-content-div-akkuMuAn3GmQAtrykQiup2 span.ipyplot-img-expand:hover {
#             cursor: zoom-in;
#         }
#
#         div[id^=ipyplot-content-div-akkuMuAn3GmQAtrykQiup2]:target {
#             transform: scale(2.5);
#             transform-origin: left top;
#             z-index: 5000;
#             top: 0;
#             left: 0;
#             position: absolute;
#         }
#
#         div[id^=ipyplot-content-div-akkuMuAn3GmQAtrykQiup2]:target span.ipyplot-img-close {
#             display: block;
#         }
#
#         div[id^=ipyplot-content-div-akkuMuAn3GmQAtrykQiup2]:target span.ipyplot-img-expand {
#             display: none;
#         }
#         </style>
#     <div id="ipyplot-imgs-container-div-akkuMuAn3GmQAtrykQiup2">
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-RDbHfErbRxbpnGNJYYPGEt" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">0</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (1).jpg</h4><img src="flowers_images\class1\dandelion (1).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-RDbHfErbRxbpnGNJYYPGEt">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-dVnT3o6g7Ryfn9GDTR8Hsh" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">1</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (10).jpg</h4><img src="flowers_images\class1\dandelion (10).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-dVnT3o6g7Ryfn9GDTR8Hsh">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-HG3bPNcbcejyBQVWVH2wXB" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">2</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (2).jpg</h4><img src="flowers_images\class1\dandelion (2).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-HG3bPNcbcejyBQVWVH2wXB">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-DDJ5ToyK3Gnf3GrSgzYHBq" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">3</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (3).jpg</h4><img src="flowers_images\class1\dandelion (3).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-DDJ5ToyK3Gnf3GrSgzYHBq">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#
#     <div class="ipyplot-placeholder-div-akkuMuAn3GmQAtrykQiup2">
#         <div id="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-eoc96gY5hRHhx3A9bWErvJ" class="ipyplot-content-div-akkuMuAn3GmQAtrykQiup2">
#             <h4 style="font-size: 12px; word-wrap: break-word;">4</h4>
#             <h4 style="font-size: 9px; padding-left: 10px; padding-right: 10px; width: 95%; word-wrap: break-word; white-space: normal;">flowers_images\class1\dandelion (4).jpg</h4><img src="flowers_images\class1\dandelion (4).jpg"/>
#             <a href="#!">
#                 <span class="ipyplot-img-close"/>
#             </a>
#             <a href="#ipyplot-content-div-akkuMuAn3GmQAtrykQiup2-eoc96gY5hRHhx3A9bWErvJ">
#                 <span class="ipyplot-img-expand"/>
#             </a>
#         </div>
#     </div>
#     </div></div></div>

# %%
class_id = ["class1", "class2", "class3", "class4"]
class_labels = ["dandelion", "rose", "sunflower", "daisy"]

df_classes = pd.DataFrame({"class_id": class_id, "class_labels": class_labels})
df_classes
# Out:
#   class_id class_labels
# 0   class1    dandelion
# 1   class2         rose
# 2   class3    sunflower
# 3   class4        daisy

# %% [markdown]
# ### Tests

# %%
import os

# Set the image file path
image_file = os.path.join(IMAGES_DIR, "class1/dandelion (1).jpg")

# Display the image (if you have a helper function for that)
display_image(image_file)

# Predict the class using your model
prediction = get_image_classification(image_file)

# Extract the class ID from the folder name
true_class_id = os.path.basename(os.path.dirname(image_file))

# Lookup the true class label from the dataframe
filtered = df_classes.loc[df_classes['class_id'] == true_class_id, 'class_labels']

# Check if a matching class was found
if not filtered.empty:
    true_class = filtered.values[0]
    print(f"True class: {true_class}\nPredicted class: {prediction}")
    print("Prediction is CORRECT" if prediction == true_class else "Prediction is INCORRECT")
else:
    print(f"Class ID '{true_class_id}' not found in df_classes")
# Out:
# Image file to classify: flowers_images\class1/dandelion (1).jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=180x240>
# True class: dandelion
# Predicted class: dandelion
# Prediction is CORRECT

# %%
import os

image_file = os.path.join(IMAGES_DIR, "class2/rose (1).jpg")

display_image(image_file)

prediction = get_image_classification(image_file)

true_class_id = os.path.basename(os.path.dirname(image_file))  # Correct way to extract class
true_class = df_classes.loc[df_classes['class_id'] == true_class_id, 'class_labels'].values[0]

print(f"True class: {true_class}\nPredicted class: {prediction}")
print("Prediction is CORRECT" if prediction == true_class else "Prediction is INCORRECT")
# Out:
# Image file to classify: flowers_images\class2/rose (1).jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>
# True class: rose
# Predicted class: rose
# Prediction is CORRECT

# %%
image_file = os.path.join(IMAGES_DIR, "class3/sunflower (1).jpg")

display_image(image_file)

prediction = get_image_classification(image_file)
true_class_id = os.path.basename(os.path.dirname(image_file))
true_class = df_classes.loc[df_classes['class_id'] == true_class_id, 'class_labels'].values[0]

print(f"True class: {true_class}\nPredicted class: {prediction}")
print("Prediction is CORRECT" if prediction == true_class else "Prediction is INCORRECT")
# Out:
# Image file to classify: flowers_images\class3/sunflower (1).jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x240>
# True class: sunflower
# Predicted class: sunflower
# Prediction is CORRECT

# %%
image_file = os.path.join(IMAGES_DIR, "class4/daisy (1).jpg")

display_image(image_file)

prediction = get_image_classification(image_file)
true_class_id = os.path.basename(os.path.dirname(image_file))
true_class = df_classes.loc[df_classes['class_id'] == true_class_id, 'class_labels'].values[0]

print(f"True class: {true_class}\nPredicted class: {prediction}")
print("Prediction is CORRECT" if prediction == true_class else "Prediction is INCORRECT")
# Out:
# Image file to classify: flowers_images\class4/daisy (1).jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x375>
# True class: daisy
# Predicted class: daisy
# Prediction is CORRECT

# %% [markdown]
# ## Confusion matrix

# %%
results = []
idx = 1

for root, dirs, files in os.walk(IMAGES_DIR):
    for file in files:
        file_path = os.path.join(root, file)
        try:
            # True label
            true_labels = df_classes.loc[df_classes['class_id'] ==
                                         os.path.basename(root),
                                         'class_labels'].values[0]
            # Predicted label with GPT-4o
            predicted_labels = get_image_classification(file_path)
            print(
                f"{idx:3} {file_path:50} True label = {true_labels:15} Predicted label = {predicted_labels}"
            )
            results.append({
                "filename": file,
                "true_labels": true_labels,
                "predicted_labels": predicted_labels
            })
            idx += 1

        except Exception as e:
            print(f"Error processing {file_path}: {e}")
# Out:
# Error processing flowers_images\img6: index 0 is out of bounds for axis 0 with size 0
#   1 flowers_images\class1\dandelion (1).jpg            True label = dandelion       Predicted label = dandelion
#   2 flowers_images\class1\dandelion (10).jpg           True label = dandelion       Predicted label = dandelion
#   3 flowers_images\class1\dandelion (2).jpg            True label = dandelion       Predicted label = dandelion
#   4 flowers_images\class1\dandelion (3).jpg            True label = dandelion       Predicted label = dandelion
#   5 flowers_images\class1\dandelion (4).jpg            True label = dandelion       Predicted label = dandelion
#   6 flowers_images\class1\dandelion (5).jpg            True label = dandelion       Predicted label = dandelion
#   7 flowers_images\class1\dandelion (6).jpg            True label = dandelion       Predicted label = dandelion
#   8 flowers_images\class1\dandelion (7).jpg            True label = dandelion       Predicted label = dandelion
#   9 flowers_images\class1\dandelion (8).jpg            True label = dandelion       Predicted label = dandelion
#  10 flowers_images\class1\dandelion (9).jpg            True label = dandelion       Predicted label = dandelion
#  11 flowers_images\class2\rose (1).jpg                 True label = rose            Predicted label = rose
#  12 flowers_images\class2\rose (10).jpg                True label = rose            Predicted label = rose
#  13 flowers_images\class2\rose (2).jpg                 True label = rose            Predicted label = rose
#  14 flowers_images\class2\rose (3).jpg                 True label = rose            Predicted label = rose
#  15 flowers_images\class2\rose (4).jpg                 True label = rose            Predicted label = rose
#  16 flowers_images\class2\rose (5).jpg                 True label = rose            Predicted label = rose
#  17 flowers_images\class2\rose (6).jpg                 True label = rose            Predicted label = unknown
#  18 flowers_images\class2\rose (7).jpg                 True label = rose            Predicted label = rose
#  19 flowers_images\class2\rose (8).jpg                 True label = rose            Predicted label = rose
#  20 flowers_images\class2\rose (9).jpg                 True label = rose            Predicted label = rose
#  21 flowers_images\class3\sunflower (1).jpg            True label = sunflower       Predicted label = sunflower
#  22 flowers_images\class3\sunflower (10).jpg           True label = sunflower       Predicted label = sunflower
#  23 flowers_images\class3\sunflower (2).jpg            True label = sunflower       Predicted label = sunflower
#  24 flowers_images\class3\sunflower (3).jpg            True label = sunflower       Predicted label = sunflower
#  25 flowers_images\class3\sunflower (4).jpg            True label = sunflower       Predicted label = sunflower
#  26 flowers_images\class3\sunflower (5).jpg            True label = sunflower       Predicted label = sunflower
#  27 flowers_images\class3\sunflower (6).jpg            True label = sunflower       Predicted label = sunflower
#  28 flowers_images\class3\sunflower (7).jpg            True label = sunflower       Predicted label = sunflower
#  29 flowers_images\class3\sunflower (8).jpg            True label = sunflower       Predicted label = sunflower
#  30 flowers_images\class3\sunflower (9).jpg            True label = sunflower       Predicted label = sunflower
#  31 flowers_images\class4\daisy (1).jpg                True label = daisy           Predicted label = daisy
#  32 flowers_images\class4\daisy (10).jpg               True label = daisy           Predicted label = daisy
#  33 flowers_images\class4\daisy (2).jpg                True label = daisy           Predicted label = daisy
#  34 flowers_images\class4\daisy (3).jpg                True label = daisy           Predicted label = daisy
#  35 flowers_images\class4\daisy (4).jpg                True label = daisy           Predicted label = daisy
#  36 flowers_images\class4\daisy (5).jpg                True label = daisy           Predicted label = daisy
#  37 flowers_images\class4\daisy (6).jpg                True label = daisy           Predicted label = daisy
#  38 flowers_images\class4\daisy (7).jpg                True label = daisy           Predicted label = daisy
#  39 flowers_images\class4\daisy (8).jpg                True label = daisy           Predicted label = daisy
#  40 flowers_images\class4\daisy (9).jpg                True label = daisy           Predicted label = daisy

# %%
print(f"Total of processed images = {idx-1}")
# Out:
# Total of processed images = 40

# %%
df = pd.DataFrame(results)
df
# Out:
#               filename true_labels predicted_labels
# 0    dandelion (1).jpg   dandelion        dandelion
# 1   dandelion (10).jpg   dandelion        dandelion
# 2    dandelion (2).jpg   dandelion        dandelion
# 3    dandelion (3).jpg   dandelion        dandelion
# 4    dandelion (4).jpg   dandelion        dandelion
# 5    dandelion (5).jpg   dandelion        dandelion
# 6    dandelion (6).jpg   dandelion        dandelion
# 7    dandelion (7).jpg   dandelion        dandelion
# 8    dandelion (8).jpg   dandelion        dandelion
# 9    dandelion (9).jpg   dandelion        dandelion
# 10        rose (1).jpg        rose             rose
# 11       rose (10).jpg        rose             rose
# 12        rose (2).jpg        rose             rose
# 13        rose (3).jpg        rose             rose
# 14        rose (4).jpg        rose             rose
# 15        rose (5).jpg        rose             rose
# 16        rose (6).jpg        rose          unknown
# 17        rose (7).jpg        rose             rose
# 18        rose (8).jpg        rose             rose
# 19        rose (9).jpg        rose             rose
# 20   sunflower (1).jpg   sunflower        sunflower
# 21  sunflower (10).jpg   sunflower        sunflower
# 22   sunflower (2).jpg   sunflower        sunflower
# 23   sunflower (3).jpg   sunflower        sunflower
# 24   sunflower (4).jpg   sunflower        sunflower
# 25   sunflower (5).jpg   sunflower        sunflower
# 26   sunflower (6).jpg   sunflower        sunflower
# 27   sunflower (7).jpg   sunflower        sunflower
# 28   sunflower (8).jpg   sunflower        sunflower
# 29   sunflower (9).jpg   sunflower        sunflower
# 30       daisy (1).jpg       daisy            daisy
# 31      daisy (10).jpg       daisy            daisy
# 32       daisy (2).jpg       daisy            daisy
# 33       daisy (3).jpg       daisy            daisy
# 34       daisy (4).jpg       daisy            daisy
# 35       daisy (5).jpg       daisy            daisy
# 36       daisy (6).jpg       daisy            daisy
# 37       daisy (7).jpg       daisy            daisy
# 38       daisy (8).jpg       daisy            daisy
# 39       daisy (9).jpg       daisy            daisy

# %%
print("True label distribution")

df['true_labels'].value_counts(sort=False).sort_index().plot(kind='barh')
plt.xlabel('Labels')
plt.ylabel('Count')
plt.title('Label Frequency')
plt.show()
# Out:
# True label distribution

# %%
print("Predicted labels distribution")

df['predicted_labels'].value_counts(sort=False).sort_index().plot(kind='barh')
plt.xlabel('Labels')
plt.ylabel('Count')
plt.title('Label Frequency')
plt.show()
# Out:
# Predicted labels distribution

# %%
# Convert to numpy arrays
y_true = df[['true_labels']].to_numpy()
y_pred = df[['predicted_labels']].to_numpy()
labels = np.unique(np.concatenate([y_true, y_pred]))

# Confusion matrix
cm = confusion_matrix(y_true, y_pred, labels=labels)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
fig, ax = plt.subplots(figsize=(8, 8))
disp.plot(cmap=plt.cm.Blues, ax=ax, colorbar=False)

for (i, j), value in np.ndenumerate(cm):
    ax.text(j,
            i,
            f"{value}",
            ha="center",
            va="center",
            fontsize=10,
            color="red")

ax.set_title("Confusion Matrix of image classification with Azure OpenAI gpt-4o base model",
             fontsize=12,
             pad=20)

ax.set_xlabel("Predicted class", fontsize=12, labelpad=10)
ax.set_ylabel("True class", fontsize=12, labelpad=10)
ax.xaxis.set_label_position("top")
ax.xaxis.tick_top()
ax.tick_params(axis='both', which='major', labelsize=8)
ax.set_xticks(np.arange(len(class_labels)), minor=True)
ax.set_yticks(np.arange(len(class_labels)), minor=True)
ax.grid(which="minor", color="black", linestyle="--", linewidth=1)
plt.subplots_adjust(bottom=0.1, top=0.9, left=0.15, right=0.85)

plt.show()

# %%
print(classification_report(y_true, y_pred, target_names=labels, zero_division=0))
# Out:
#               precision    recall  f1-score   support
#
#        daisy       1.00      1.00      1.00        10
#    dandelion       1.00      1.00      1.00        10
#         rose       1.00      0.90      0.95        10
#    sunflower       1.00      1.00      1.00        10
#      unknown       0.00      0.00      0.00         0
#
#     accuracy                           0.97        40
#    macro avg       0.80      0.78      0.79        40
# weighted avg       1.00      0.97      0.99        40

# %%
accuracy = np.diag(cm).sum() / cm.sum()
print(f'Accuracy = {accuracy:.2f}')
# Out:
# Accuracy = 0.97

# %% [markdown]
# > Azure OpenAI gpt-4o "Zero-shot classification" refers to the ability of a model to correctly classify data it has never seen before, without any specific custom training on that particular type of data. The model is performing reasonably well despite on this kind of usual flower images.
